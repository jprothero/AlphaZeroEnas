# %%
from lr_find import lr_finder

# %%
learn = lr_finder("controller")
# Out:
# Successfully loaded 460 memories
# ...
#  95%|█████████▌| 19/20 [02:37<00:08,  8.27s/it, loss=tensor([nan.])]

# %%
learn.sched.plot()

# %%
3e-2
# Out:
# 0.03

# %%
[lrn.sched.plot() for lrn in learn]
# Out:
# [None, None, None, None]

# %%
7e-3
# Out:
# 0.007

# %%
#indices that are okayish: 1

# %%
import numpy as np
a = np.linspace(1e-5, 10, 40)

# %%
a[-int(len(a)*.55):][0]
# Out:
# 4.61539
