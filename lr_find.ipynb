# %%
from lr_find import lr_finder

# %%
learn = lr_finder("controller")
# Out:
# Successfully loaded 1743 memories
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
#   0%|          | 0/20 [00:00<?, ?it/s]> /home/jprothero/New-Projects/AlphaZeroEnas/lib/ENAS_MP.py(579)train_controller()
#     578                 set_trace()
# --> 579                 score /= self.filters[trajectory[-1]]
#     580
#
# ipdb> trajectory[-1]
# *** IndexError: list index out of range
# ipdb> trajectory
# []

# %%
learn.sched.plot()

# %%
7e-2
# Out:
# 0.1

# %%
[lrn.sched.plot() for lrn in learn]
# Out:
# [None, None, None, None]

# %%
7e-3
# Out:
# 0.007

# %%
#indices that are okayish: 1

# %%
import numpy as np
a = np.linspace(1e-5, 10, 40)

# %%
a[-int(len(a)*.55):][0]
# Out:
# 4.61539
